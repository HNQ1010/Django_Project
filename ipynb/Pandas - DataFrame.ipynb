# %% [markdown]
# ## Pandas - DataFrame
# Probably the most important data structure of pandas is the DataFrame. It's a tabular structure tightly integrated with Series.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame( {'Population': [35.467, 63.951, 80.94, 60.665, 127.061, 64.511, 318.523],
                   'GDP': [1785387, 2833687, 3874437, 2167744, 4602367, 2950039, 17348075],
                   'Surface Area': [9984670, 640679, 357114, 301336, 377930, 242495, 9525067],
                   'HDI': [0.913, 0.888, 0.0916, 0.873, 0.891, 0.907, 0.915],
                   'Continent': ['America', 'Europe', 'Europe', 'Europe', 'Asia', 'Europe', 'America']})
#                  ,columns = ['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'] )
# the column attribute is optional

# %%
df
# Out:
#    Population       GDP  Surface Area     HDI Continent
# 0      35.467   1785387       9984670  0.9130   America
# 1      63.951   2833687        640679  0.8880    Europe
# 2      80.940   3874437        357114  0.0916    Europe
# 3      60.665   2167744        301336  0.8730    Europe
# 4     127.061   4602367        377930  0.8910      Asia
# 5      64.511   2950039        242495  0.9070    Europe
# 6     318.523  17348075       9525067  0.9150   America

# %% [markdown]
# DataFrame is also have indexes. Pandas assigned a numeric, autoincremental index automatically to each 'row' in our DataFrame. To change
# the indexes to the country name, use index like series.

# %%
df.index = ['Canada', 'France', 'Germany', 'Italy', 'Japan', 'UK', 'US']

# %%
df
# Out:
#          Population       GDP  Surface Area     HDI Continent
# Canada       35.467   1785387       9984670  0.9130   America
# France       63.951   2833687        640679  0.8880    Europe
# Germany      80.940   3874437        357114  0.0916    Europe
# Italy        60.665   2167744        301336  0.8730    Europe
# Japan       127.061   4602367        377930  0.8910      Asia
# UK           64.511   2950039        242495  0.9070    Europe
# US          318.523  17348075       9525067  0.9150   America

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %%
df.size
# Out:
# 35

# %%
df.shape # not included index column
# Out:
# (7, 5)

# %%
df.describe()
# Out:
#        Population           GDP  Surface Area       HDI
# count    7.000000  7.000000e+00  7.000000e+00  7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.782657
# std     97.249970  5.494020e+06  4.576187e+06  0.305102
# min     35.467000  1.785387e+06  2.424950e+05  0.091600
# 25%     62.308000  2.500716e+06  3.292250e+05  0.880500
# 50%     64.511000  2.950039e+06  3.779300e+05  0.891000
# 75%    104.000500  4.238402e+06  5.082873e+06  0.910000
# max    318.523000  1.734808e+07  9.984670e+06  0.915000

# %%
df.dtypes
# Out:
# Population      float64
# GDP               int64
# Surface Area      int64
# HDI             float64
# Continent        object
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# int64      2
# float64    2
# object     1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to US
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    7 non-null      float64
#  1   GDP           7 non-null      int64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 336.0+ bytes

# %% [markdown]
# ### Indexing, Selection and Slicing
# Individual columns in the DataFrame can be selected with regular indexing. Each column is represented as a Series.
# * The **df[]** access the dataframe at vertical side (or columns)
# * The **loc[first_argument] and iloc[first_argument]** access the dataframe at horizontal side(row)
# * The **loc[first_arg, second_arg] and iloc[first_arg, second_arg]** access the dataframe from both side(row and column)

# %%
df['Population']
# Out:
# Canada      35.467
# France      63.951
# Germany     80.940
# Italy       60.665
# Japan      127.061
# UK          64.511
# US         318.523
# Name: Population, dtype: float64

# %% [markdown]
# Note that the index of the returned Series is the same as the DataFrame one. And is name is the name of the column. If you're working
# on a notebook and want to see a more DataFrame like format you can use the 'to_frame' method.

# %%
df['Population'].to_frame()
# Out:
#          Population
# Canada       35.467
# France       63.951
# Germany      80.940
# Italy        60.665
# Japan       127.061
# UK           64.511
# US          318.523

# %% [markdown]
# Multiple columns can be choosen same as numpy and series. And in this case, the result is different with DataFrame.(like to_frame())

# %%
df[['Population', 'GDP']]
# Out:
#          Population       GDP
# Canada       35.467   1785387
# France       63.951   2833687
# Germany      80.940   3874437
# Italy        60.665   2167744
# Japan       127.061   4602367
# UK           64.511   2950039
# US          318.523  17348075

# %% [markdown]
# Slicing work differently, it acts at **'row level'** and can be counter intuitive.

# %%
df[1:3]
# Out:
#          Population      GDP  Surface Area     HDI Continent
# France       63.951  2833687        640679  0.8880    Europe
# Germany      80.940  3874437        357114  0.0916    Europe

# %% [markdown]
# **Row level** works better with **loc** and **iloc** which are recommended over regular 'direct' slicing (df[:])
#
# And if the row access is one, the result will be transposed with the DataFrame

# %%
df.loc['Italy'] # result be transposed,
# Out:
# Population       60.665
# GDP             2167744
# Surface Area     301336
# HDI               0.873
# Continent        Europe
# Name: Italy, dtype: object

# %%
df.loc['Italy':'US']
# Out:
#        Population       GDP  Surface Area    HDI Continent
# Italy      60.665   2167744        301336  0.873    Europe
# Japan     127.061   4602367        377930  0.891      Asia
# UK         64.511   2950039        242495  0.907    Europe
# US        318.523  17348075       9525067  0.915   America

# %% [markdown]
# And with the second argument, you can add the column(s) that you want to get:

# %%
df.loc['Italy', 'Population'], df.loc['Italy':'US', ['Population', 'GDP']]
# Out:
# (60.665,
#         Population       GDP
#  Italy      60.665   2167744
#  Japan     127.061   4602367
#  UK         64.511   2950039
#  US        318.523  17348075)

# %%
df.iloc[0,3]
# Out:
# 0.913

# %%
df.iloc[[0,3,-1]] # with 3 and greater element, must use [[]]
# Out:
#         Population       GDP  Surface Area    HDI Continent
# Canada      35.467   1785387       9984670  0.913   America
# Italy       60.665   2167744        301336  0.873    Europe
# US         318.523  17348075       9525067  0.915   America

# %%
df.iloc[0:3,3], df.iloc[0:3, 0:3], df.iloc[0:3]
# Out:
# (Canada     0.9130
#  France     0.8880
#  Germany    0.0916
#  Name: HDI, dtype: float64,
#           Population      GDP  Surface Area
#  Canada       35.467  1785387       9984670
#  France       63.951  2833687        640679
#  Germany      80.940  3874437        357114,
#           Population      GDP  Surface Area     HDI Continent
#  Canada       35.467  1785387       9984670  0.9130   America
#  France       63.951  2833687        640679  0.8880    Europe
#  Germany      80.940  3874437        357114  0.0916    Europe)

# %%
df.iloc[0::2] # start location (0), jump over:2
# Out:
#          Population       GDP  Surface Area     HDI Continent
# Canada       35.467   1785387       9984670  0.9130   America
# Germany      80.940   3874437        357114  0.0916    Europe
# Japan       127.061   4602367        377930  0.8910      Asia
# US          318.523  17348075       9525067  0.9150   America

# %% [markdown]
# > **RECOMMENDED**: Always use loc and iloc to avoid ambiguity, specially with numeric indexes in DataFrame

# %% [markdown]
# ### Conditional Selection (boolean arrays)
# We saw conditional selection applied to Series and it'll work in the same way for DataFrame, or DataFrame is a collection of Series.

# %%
df['Population'] > 70
# Out:
# Canada     False
# France     False
# Germany     True
# Italy      False
# Japan       True
# UK         False
# US          True
# Name: Population, dtype: bool

# %%
df.loc[df['Population']>70]
# Out:
#          Population       GDP  Surface Area     HDI Continent
# Germany      80.940   3874437        357114  0.0916    Europe
# Japan       127.061   4602367        377930  0.8910      Asia
# US          318.523  17348075       9525067  0.9150   America

# %%
df.loc[df['Population']>80, ['Population', 'GDP']]
# Out:
#          Population       GDP
# Germany      80.940   3874437
# Japan       127.061   4602367
# US          318.523  17348075

# %% [markdown]
# ### Dropping stuff
# Opposed to the concept of selection, we have 'dropping'. Insted of pointing out which values you'd like to select, you could point
# which ones you'd like to **drop**

# %%
df
# Out:
#          Population       GDP  Surface Area     HDI Continent
# Canada       35.467   1785387       9984670  0.9130   America
# France       63.951   2833687        640679  0.8880    Europe
# Germany      80.940   3874437        357114  0.0916    Europe
# Italy        60.665   2167744        301336  0.8730    Europe
# Japan       127.061   4602367        377930  0.8910      Asia
# UK           64.511   2950039        242495  0.9070    Europe
# US          318.523  17348075       9525067  0.9150   America

# %%
df.drop('Canada')
# Out:
#          Population       GDP  Surface Area     HDI Continent
# France       63.951   2833687        640679  0.8880    Europe
# Germany      80.940   3874437        357114  0.0916    Europe
# Italy        60.665   2167744        301336  0.8730    Europe
# Japan       127.061   4602367        377930  0.8910      Asia
# UK           64.511   2950039        242495  0.9070    Europe
# US          318.523  17348075       9525067  0.9150   America

# %%
df.drop(columns='Population'), df.drop(columns= ['Population', 'GDP'])
# Out:
# (              GDP  Surface Area     HDI Continent
#  Canada    1785387       9984670  0.9130   America
#  France    2833687        640679  0.8880    Europe
#  Germany   3874437        357114  0.0916    Europe
#  Italy     2167744        301336  0.8730    Europe
#  Japan     4602367        377930  0.8910      Asia
#  UK        2950039        242495  0.9070    Europe
#  US       17348075       9525067  0.9150   America,
#           Surface Area     HDI Continent
#  Canada        9984670  0.9130   America
#  France         640679  0.8880    Europe
#  Germany        357114  0.0916    Europe
#  Italy          301336  0.8730    Europe
#  Japan          377930  0.8910      Asia
#  UK             242495  0.9070    Europe
#  US            9525067  0.9150   America)

# %%
df.drop(['Italy', 'Japan'], axis=0) # or axis = rows
# Out:
#          Population       GDP  Surface Area     HDI Continent
# Canada       35.467   1785387       9984670  0.9130   America
# France       63.951   2833687        640679  0.8880    Europe
# Germany      80.940   3874437        357114  0.0916    Europe
# UK           64.511   2950039        242495  0.9070    Europe
# US          318.523  17348075       9525067  0.9150   America

# %%
df.drop(['Population', 'GDP'], axis=1) # or axis = columns
# Out:
#          Surface Area     HDI Continent
# Canada        9984670  0.9130   America
# France         640679  0.8880    Europe
# Germany        357114  0.0916    Europe
# Italy          301336  0.8730    Europe
# Japan          377930  0.8910      Asia
# UK             242495  0.9070    Europe
# US            9525067  0.9150   America

# %% [markdown]
# All these drop example return new DataFrame. If you'd like to modify it **in place**, you can use the **inplace** attribute to actually modify original DataFrame

# %%
df.drop(columns='Language', inplace=True)

# %% [markdown]
# ### Operations
# Normally, the operation don't change the underlying DataFrame, if you want to use the change, you should assign a new name for the result set that you want. Eg: new_name= df_operations

# %%
df[['Population', 'GDP']] * 100 # you can use another operation : + - / ** ...
# Out:
#          Population         GDP
# Canada       3546.7   178538700
# France       6395.1   283368700
# Germany      8094.0   387443700
# Italy        6066.5   216774400
# Japan       12706.1   460236700
# UK           6451.1   295003900
# US          31852.3  1734807500

# %% [markdown]
# Operation with Series work at a column level, broadcasting down the rows (which can be counter intuitive)

# %%
crisis = pd.Series([-1_000_000, -0.3], index=['GDP', 'HDI'])

# %%
df[['GDP', 'HDI']] + crisis
# Out:
#                 GDP     HDI
# Canada     785387.0  0.6130
# France    1833687.0  0.5880
# Germany   2874437.0 -0.2084
# Italy     1167744.0  0.5730
# Japan     3602367.0  0.5910
# UK        1950039.0  0.6070
# US       16348075.0  0.6150

# %% [markdown]
# ### Modifying DataFrames
# It simple and intuitive, you can add columns, or replace values for columns without issues

# %%
langs = pd.Series(['French', 'German', 'Italian'], index= ['France', 'Germany', 'Italy'], name = 'language')
langs
# Out:
# France      French
# Germany     German
# Italy      Italian
# Name: language, dtype: object

# %%
df['Language'] = langs

# %%
df
# Out:
#          Population       GDP  Surface Area     HDI Continent Language
# Canada       35.467   1785387       9984670  0.9130   America      NaN
# France       63.951   2833687        640679  0.8880    Europe   French
# Germany      80.940   3874437        357114  0.0916    Europe   German
# Italy        60.665   2167744        301336  0.8730    Europe  Italian
# Japan       127.061   4602367        377930  0.8910      Asia      NaN
# UK           64.511   2950039        242495  0.9070    Europe      NaN
# US          318.523  17348075       9525067  0.9150   America      NaN

# %% [markdown]
# ### Replacing values per columns

# %%
df['Language'] = 'English'
df
# Out:
#          Population         GDP  Surface Area     HDI Continent Language
# Canada       35.467   1785387.0     9984670.0  0.9130   America  English
# France       63.951   2833687.0      640679.0  0.8880    Europe  English
# Germany      80.940   3874437.0      357114.0  0.0916    Europe  English
# Italy        60.665   2167744.0      301336.0  0.8730    Europe  English
# Japan       127.061   4602367.0      377930.0  0.8910      Asia  English
# UK           64.511   2950039.0      242495.0  0.9070    Europe  English
# US          318.523  17348075.0     9525067.0  0.9150   America  English
# 0               NaN         NaN           NaN     NaN       NaN  English

# %%
df.loc['Canada'] = 'Canadian'

# %%
df
# Out:
#          Population         GDP  Surface Area     HDI Continent  Language
# Canada       35.467   1785387.0     9984670.0  0.9130   America  Canadian
# France       63.951   2833687.0      640679.0  0.8880    Europe   English
# Germany      80.940   3874437.0      357114.0  0.0916    Europe   English
# Italy        60.665   2167744.0      301336.0  0.8730    Europe   English
# Japan       127.061   4602367.0      377930.0  0.8910      Asia   English
# UK           64.511   2950039.0      242495.0  0.9070    Europe   English
# US          318.523  17348075.0     9525067.0  0.9150   America   English
# 0               NaN         NaN           NaN     NaN       NaN  Canadian

# %%
df.loc['Canada','Language'] = 'English'
df
# Out:
#          Population         GDP  Surface Area     HDI Continent Language
# Canada       35.467   1785387.0     9984670.0  0.9130   America  English
# France       63.951   2833687.0      640679.0  0.8880    Europe  English
# Germany      80.940   3874437.0      357114.0  0.0916    Europe  English
# Italy        60.665   2167744.0      301336.0  0.8730    Europe  English
# Japan       127.061   4602367.0      377930.0  0.8910      Asia  English
# UK           64.511   2950039.0      242495.0  0.9070    Europe  English
# US          318.523  17348075.0     9525067.0  0.9150   America  English
# 0               NaN         NaN           NaN     NaN       NaN  English

# %% [markdown]
# ### Renaming Columns

# %%
df.rename(columns = {'HDI':'Human Development Index',
                    'Anual Popcorn Consumption' :'APC'},
                      index = {'US': 'United State',
                              'UK': 'United Kingdom',
                              'Argentia': 'AG'})
# Out:
#                 Population         GDP  Surface Area  Human Development Index  \
# Canada              35.467   1785387.0     9984670.0                   0.9130
# France              63.951   2833687.0      640679.0                   0.8880
# Germany             80.940   3874437.0      357114.0                   0.0916
# Italy               60.665   2167744.0      301336.0                   0.8730
# Japan              127.061   4602367.0      377930.0                   0.8910
# United Kingdom      64.511   2950039.0      242495.0                   0.9070
# United State       318.523  17348075.0     9525067.0                   0.9150
#
#                Continent
# Canada           America
# France            Europe
# Germany           Europe
# Italy             Europe
# Japan               Asia
# United Kingdom    Europe
# United State     America

# %%
df.rename(index = lambda x:x.lower())
# Out:
#          Population         GDP  Surface Area     HDI Continent
# canada       35.467   1785387.0     9984670.0  0.9130   America
# france       63.951   2833687.0      640679.0  0.8880    Europe
# germany      80.940   3874437.0      357114.0  0.0916    Europe
# italy        60.665   2167744.0      301336.0  0.8730    Europe
# japan       127.061   4602367.0      377930.0  0.8910      Asia
# uk           64.511   2950039.0      242495.0  0.9070    Europe
# us          318.523  17348075.0     9525067.0  0.9150   America

# %%
df.rename(index = str.upper)
# Out:
#          Population         GDP  Surface Area     HDI Continent
# CANADA       35.467   1785387.0     9984670.0  0.9130   America
# FRANCE       63.951   2833687.0      640679.0  0.8880    Europe
# GERMANY      80.940   3874437.0      357114.0  0.0916    Europe
# ITALY        60.665   2167744.0      301336.0  0.8730    Europe
# JAPAN       127.061   4602367.0      377930.0  0.8910      Asia
# UK           64.511   2950039.0      242495.0  0.9070    Europe
# US          318.523  17348075.0     9525067.0  0.9150   America

# %% [markdown]
# ### Adding values

# %% [markdown]
# Using append() method

# %%
df.append(pd.Series({'Population':3, 'GDP':5}, name='China'))
# Out:
#          Population         GDP  Surface Area     HDI Continent
# Canada       35.467   1785387.0     9984670.0  0.9130   America
# France       63.951   2833687.0      640679.0  0.8880    Europe
# Germany      80.940   3874437.0      357114.0  0.0916    Europe
# Italy        60.665   2167744.0      301336.0  0.8730    Europe
# Japan       127.061   4602367.0      377930.0  0.8910      Asia
# UK           64.511   2950039.0      242495.0  0.9070    Europe
# US          318.523  17348075.0     9525067.0  0.9150   America
# China         3.000         5.0           NaN     NaN       NaN

# %% [markdown]
# Or you can directly set the new index and values to the DataFrame

# %%
df.loc['China'] = pd.Series({'Population':1_400_000_000, 'Continent': 'Asia'})

# %%
df
# Out:
#            Population         GDP  Surface Area     HDI Continent
# Canada   3.546700e+01   1785387.0     9984670.0  0.9130   America
# France   6.395100e+01   2833687.0      640679.0  0.8880    Europe
# Germany  8.094000e+01   3874437.0      357114.0  0.0916    Europe
# Italy    6.066500e+01   2167744.0      301336.0  0.8730    Europe
# Japan    1.270610e+02   4602367.0      377930.0  0.8910      Asia
# UK       6.451100e+01   2950039.0      242495.0  0.9070    Europe
# US       3.185230e+02  17348075.0     9525067.0  0.9150   America
# China    1.400000e+09         NaN           NaN     NaN      Asia

# %%
df.drop('China', inplace=True)

# %%
df
# Out:
#          Population         GDP  Surface Area     HDI Continent
# Canada       35.467   1785387.0     9984670.0  0.9130   America
# France       63.951   2833687.0      640679.0  0.8880    Europe
# Germany      80.940   3874437.0      357114.0  0.0916    Europe
# Italy        60.665   2167744.0      301336.0  0.8730    Europe
# Japan       127.061   4602367.0      377930.0  0.8910      Asia
# UK           64.511   2950039.0      242495.0  0.9070    Europe
# US          318.523  17348075.0     9525067.0  0.9150   America

# %% [markdown]
# ### More radical index changes

# %%
df.reset_index()
# Out:
#      index  Population         GDP  Surface Area     HDI Continent
# 0   Canada      35.467   1785387.0     9984670.0  0.9130   America
# 1   France      63.951   2833687.0      640679.0  0.8880    Europe
# 2  Germany      80.940   3874437.0      357114.0  0.0916    Europe
# 3    Italy      60.665   2167744.0      301336.0  0.8730    Europe
# 4    Japan     127.061   4602367.0      377930.0  0.8910      Asia
# 5       UK      64.511   2950039.0      242495.0  0.9070    Europe
# 6       US     318.523  17348075.0     9525067.0  0.9150   America

# %%
df.set_index('Population')
# Out:
#                    GDP  Surface Area     HDI Continent
# Population
# 35.467       1785387.0     9984670.0  0.9130   America
# 63.951       2833687.0      640679.0  0.8880    Europe
# 80.940       3874437.0      357114.0  0.0916    Europe
# 60.665       2167744.0      301336.0  0.8730    Europe
# 127.061      4602367.0      377930.0  0.8910      Asia
# 64.511       2950039.0      242495.0  0.9070    Europe
# 318.523     17348075.0     9525067.0  0.9150   America

# %%
df
# Out:
#          Population         GDP  Surface Area     HDI Continent
# Canada       35.467   1785387.0     9984670.0  0.9130   America
# France       63.951   2833687.0      640679.0  0.8880    Europe
# Germany      80.940   3874437.0      357114.0  0.0916    Europe
# Italy        60.665   2167744.0      301336.0  0.8730    Europe
# Japan       127.061   4602367.0      377930.0  0.8910      Asia
# UK           64.511   2950039.0      242495.0  0.9070    Europe
# US          318.523  17348075.0     9525067.0  0.9150   America

# %% [markdown]
# ### Creating columns from other column
# Altering a DataFrame often involves combining different oclumns into another. For example, in our Countries analysis, we could try to calculate the 'GDP per capita', which is just, GDP/ Population

# %%
df[['Population', 'GDP']]
# Out:
#          Population         GDP
# Canada       35.467   1785387.0
# France       63.951   2833687.0
# Germany      80.940   3874437.0
# Italy        60.665   2167744.0
# Japan       127.061   4602367.0
# UK           64.511   2950039.0
# US          318.523  17348075.0

# %% [markdown]
# The regular pandas away of expressing that, is just dividing each series:

# %%
df['GDP']/ df['Population']
# Out:
# Canada     50339.385908
# France     44310.284437
# Germany    47868.013343
# Italy      35733.025633
# Japan      36221.712406
# UK         45729.239975
# US         54464.120330
# dtype: float64

# %% [markdown]
# The result of that operation is just another series that you can add to original DataFrame.

# %%
df['GDP per capita'] = df['GDP'] / df['Population']

# %%
df
# Out:
#          Population         GDP  Surface Area     HDI Continent  \
# Canada       35.467   1785387.0     9984670.0  0.9130   America
# France       63.951   2833687.0      640679.0  0.8880    Europe
# Germany      80.940   3874437.0      357114.0  0.0916    Europe
# Italy        60.665   2167744.0      301336.0  0.8730    Europe
# Japan       127.061   4602367.0      377930.0  0.8910      Asia
# UK           64.511   2950039.0      242495.0  0.9070    Europe
# US          318.523  17348075.0     9525067.0  0.9150   America
#
#          GDP per capita
# Canada     50339.385908
# France     44310.284437
# Germany    47868.013343
# Italy      35733.025633
# Japan      36221.712406
# UK         45729.239975
# US         54464.120330

# %% [markdown]
# ### Statistical info

# %% [markdown]
# You've already seen the describe method, which gives you a good sumary of the DataFrame. Let's explore other methods in more details:

# %%
df.head()
# Out:
#          Population        GDP  Surface Area     HDI Continent  GDP per capita
# Canada       35.467  1785387.0     9984670.0  0.9130   America    50339.385908
# France       63.951  2833687.0      640679.0  0.8880    Europe    44310.284437
# Germany      80.940  3874437.0      357114.0  0.0916    Europe    47868.013343
# Italy        60.665  2167744.0      301336.0  0.8730    Europe    35733.025633
# Japan       127.061  4602367.0      377930.0  0.8910      Asia    36221.712406
