# %%
import pandas as pd

# %% [markdown]
# Another useful pandas method is **read_html()**. This method will rad HTML tables from a given URL, a file-like objet, or raw string contain HTML, and return a list of DataFrame object.
# ### Before to do this, you have to install lxml first and foremost.

# %% [markdown]
# Open sample html for the working example.

# %%
html_string = '''
<h1 style="color:red; text-align:center"><b>SQL Server String Functions</b></h1>
    <ul>
        <table>
            <tr>
                <th>Function</th>
                <th>Description</th>
            </tr>
            <tr>
                <td>ASCII</td>
                <td>Return the ASCII code value of a character.</td>
            </tr>
            <tr>
                <td>CHAR</td>
                <td>Convert an ASCII to a character.</td>
            </tr>
            <tr>
                <td>CHARINDEX</td>
                <td>Search for a substring inside a string starting from a specified location and return the position of the substring.</td>
            </tr>
            <tr>
                <td>CONCAT</td>
                <td>Join two or more strings into one string.</td>
            </tr>
            <tr>
                <td>CONCAT_WS</td>
                <td>Concatenate multiple strings with a separator into a single string.</td>
            </tr>
            <tr>
                <td>DIFFERENCE</td>
                <td>Compare the SOUNDEX() values of two strings.</td>
            </tr>
            <tr>
                <td>SOUNDEX</td>
                <td>Return a four-character (SOUNDEX) code of a string based on how it is spoken.</td>
            </tr>
            <tr>
                <td>LEFT</td>
                <td>Extract a given a number of characters from a character string starting from the left.</td>
            </tr>
            <tr>
                <td>LEN</td>
                <td>Return a number of character of a character string.</td>
            </tr>
            <tr>
                <td>LOWER</td>
                <td>Convert a string to lowercase.</td>
            </tr>
            <tr>
                <td>LTRIM</td>
                <td>Return a new string from a specified string after removing all leading blanks.</td>
            </tr>
            <tr>
                <td>NCHAR</td>
                <td>Return the Unicode character with the specified integer code, as defined by the Unicode standard.</td>
            </tr>
            <tr>
                <td>PATINDEX</td>
                <td>Returns the starting position of the first occurrence of a pattern in a string.</td>
            </tr>
            <tr>
                <td>QUOTENAME</td>
                <td>Returns a Unicode string with the delimiters added to make the input string a valid delimited identifier.</td>
            </tr>
            <tr>
                <td>REPLACE</td>
                <td>Replace all occurrences of a substring, within a string with another substring.</td>
            </tr>
            <tr>
                <td>REPLICATE</td>
                <td>Return a string repeated a specified number of times.</td>
            </tr>
            <tr>
                <td>REVERSE</td>
                <td>Return the reverse order of a character string.</td>
            </tr>
            <tr>
                <td>RIGHT</td>
                <td>Extract a given number of characters from a character string starting from the right.</td>
            </tr>
            <tr>
                <td>RTRIM</td>
                <td>Return a new string from a specified string after removing all trailing blanks.</td>
            </tr>
            <tr>
                <td>SPACE</td>
                <td>Returns a string of repeated spaces.</td>
            </tr>
            <tr>
                <td>STR</td>
                <td>Returns character data converted from numeric data.</td>
            </tr>
            <tr>
                <td>STRING_AGG</td>
                <td>Concatenate rows of strings with a specified separator into a new string.</td>
            </tr>
            <tr>
                <td>STRING_ESCAPE</td>
                <td>Escape special characters in a string and returns a new string with escaped characters.</td>
            </tr>
            <tr>
                <td>STRING_SPLIT</td>
                <td>A table-valued function that splits a string into rows of substrings based on a specified separator.</td>
            </tr>
            <tr>
                <td>STUFF</td>
                <td>Delete a part of a string and then insert another substring into the string.</td>
            </tr>
            <tr>
                <td>SUBSTRING</td>
                <td>Extract a substring within a string starting from a specified location with a specified length.</td>
            </tr>
            <tr>
                <td>TRANSLATE</td>
                <td>Replace several single-characters, one-to-one translation in one operation.</td>
            </tr>
            <tr>
                <td>TRIM</td>
                <td>Return a new string from a specified string after removing all leading and trailing blanks.</td>
            </tr>
            <tr>
                <td>UNICODE</td>
                <td>Returns the integer value, as defined by the Unicode standard, of a character.</td>
            </tr>
            <tr>
                <td>UPPER</td>
                <td>Convert a string to UPPERCASE</td>
            </tr>
        </table>
        </ul>
        '''

# %% [markdown]
# # IPython with 2 upper letter

# %%
from IPython.core.display import display, HTML # explore more
display(HTML(html_string))
# Out:
# <h1 style="color:red; text-align:center"><b>SQL Server String Functions</b></h1>
#     <ul>
#         <table>
#             <tr>
#                 <th>Function</th>
#                 <th>Description</th>
#             </tr>
#             <tr>
#                 <td>ASCII</td>
#                 <td>Return the ASCII code value of a character.</td>
#             </tr>
#             <tr>
#                 <td>CHAR</td>
#                 <td>Convert an ASCII to a character.</td>
#             </tr>
#             <tr>
#                 <td>CHARINDEX</td>
#                 <td>Search for a substring inside a string starting from a specified location and return the position of the substring.</td>
#             </tr>
#             <tr>
#                 <td>CONCAT</td>
#                 <td>Join two or more strings into one string.</td>
#             </tr>
#             <tr>
#                 <td>CONCAT_WS</td>
#                 <td>Concatenate multiple strings with a separator into a single string.</td>
#             </tr>
#             <tr>
#                 <td>DIFFERENCE</td>
#                 <td>Compare the SOUNDEX() values of two strings.</td>
#             </tr>
#             <tr>
#                 <td>SOUNDEX</td>
#                 <td>Return a four-character (SOUNDEX) code of a string based on how it is spoken.</td>
#             </tr>
#             <tr>
#                 <td>LEFT</td>
#                 <td>Extract a given a number of characters from a character string starting from the left.</td>
#             </tr>
#             <tr>
#                 <td>LEN</td>
#                 <td>Return a number of character of a character string.</td>
#             </tr>
#             <tr>
#                 <td>LOWER</td>
#                 <td>Convert a string to lowercase.</td>
#             </tr>
#             <tr>
#                 <td>LTRIM</td>
#                 <td>Return a new string from a specified string after removing all leading blanks.</td>
#             </tr>
#             <tr>
#                 <td>NCHAR</td>
#                 <td>Return the Unicode character with the specified integer code, as defined by the Unicode standard.</td>
#             </tr>
#             <tr>
#                 <td>PATINDEX</td>
#                 <td>Returns the starting position of the first occurrence of a pattern in a string.</td>
#             </tr>
#             <tr>
#                 <td>QUOTENAME</td>
#                 <td>Returns a Unicode string with the delimiters added to make the input string a valid delimited identifier.</td>
#             </tr>
#             <tr>
#                 <td>REPLACE</td>
#                 <td>Replace all occurrences of a substring, within a string with another substring.</td>
#             </tr>
#             <tr>
#                 <td>REPLICATE</td>
#                 <td>Return a string repeated a specified number of times.</td>
#             </tr>
#             <tr>
#                 <td>REVERSE</td>
#                 <td>Return the reverse order of a character string.</td>
#             </tr>
#             <tr>
#                 <td>RIGHT</td>
#                 <td>Extract a given number of characters from a character string starting from the right.</td>
#             </tr>
#             <tr>
#                 <td>RTRIM</td>
#                 <td>Return a new string from a specified string after removing all trailing blanks.</td>
#             </tr>
#             <tr>
#                 <td>SPACE</td>
#                 <td>Returns a string of repeated spaces.</td>
#             </tr>
#             <tr>
#                 <td>STR</td>
#                 <td>Returns character data converted from numeric data.</td>
#             </tr>
#             <tr>
#                 <td>STRING_AGG</td>
#                 <td>Concatenate rows of strings with a specified separator into a new string.</td>
#             </tr>
#             <tr>
#                 <td>STRING_ESCAPE</td>
#                 <td>Escape special characters in a string and returns a new string with escaped characters.</td>
#             </tr>
#             <tr>
#                 <td>STRING_SPLIT</td>
#                 <td>A table-valued function that splits a string into rows of substrings based on a specified separator.</td>
#             </tr>
#             <tr>
#                 <td>STUFF</td>
#                 <td>Delete a part of a string and then insert another substring into the string.</td>
#             </tr>
#             <tr>
#                 <td>SUBSTRING</td>
#                 <td>Extract a substring within a string starting from a specified location with a specified length.</td>
#             </tr>
#             <tr>
#                 <td>TRANSLATE</td>
#                 <td>Replace several single-characters, one-to-one translation in one operation.</td>
#             </tr>
#             <tr>
#                 <td>TRIM</td>
#                 <td>Return a new string from a specified string after removing all leading and trailing blanks.</td>
#             </tr>
#             <tr>
#                 <td>UNICODE</td>
#                 <td>Returns the integer value, as defined by the Unicode standard, of a character.</td>
#             </tr>
#             <tr>
#                 <td>UPPER</td>
#                 <td>Convert a string to UPPERCASE</td>
#             </tr>
#         </table>
#         </ul>

# %%
import sys
sys.path
# Out:
# ['D:\\Python\\PY_Django\\SQLTutorial\\SQLTutorial',
#  'c:\\users\\thanh phat us\\appdata\\local\\programs\\python\\python39\\python39.zip',
#  'c:\\users\\thanh phat us\\appdata\\local\\programs\\python\\python39\\DLLs',
#  'c:\\users\\thanh phat us\\appdata\\local\\programs\\python\\python39\\lib',
#  'c:\\users\\thanh phat us\\appdata\\local\\programs\\python\\python39',
#  '',
#  'C:\\Users\\THANH PHAT US\\AppData\\Roaming\\Python\\Python39\\site-packages',
#  'c:\\users\\thanh phat us\\appdata\\local\\programs\\python\\python39\\lib\\site-packages',
#  'c:\\users\\thanh phat us\\appdata\\local\\programs\\python\\python39\\lib\\site-packages\\win32',
#  'c:\\users\\thanh phat us\\appdata\\local\\programs\\python\\python39\\lib\\site-packages\\win32\\lib',
#  'c:\\users\\thanh phat us\\appdata\\local\\programs\\python\\python39\\lib\\site-packages\\Pythonwin',
#  'c:\\users\\thanh phat us\\appdata\\local\\programs\\python\\python39\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\THANH PHAT US\\.ipython']

# %%
dfs = pd.read_html(html_string)
dfs
# Out:
# [         Function                                        Description
#  0           ASCII        Return the ASCII code value of a character.
#  1            CHAR                   Convert an ASCII to a character.
#  2       CHARINDEX  Search for a substring inside a string startin...
#  3          CONCAT          Join two or more strings into one string.
#  4       CONCAT_WS  Concatenate multiple strings with a separator ...
#  5      DIFFERENCE       Compare the SOUNDEX() values of two strings.
#  6         SOUNDEX  Return a four-character (SOUNDEX) code of a st...
#  7            LEFT  Extract a given a number of characters from a ...
#  8             LEN  Return a number of character of a character st...
#  9           LOWER                     Convert a string to lowercase.
#  10          LTRIM  Return a new string from a specified string af...
#  11          NCHAR  Return the Unicode character with the specifie...
#  12       PATINDEX  Returns the starting position of the first occ...
#  13      QUOTENAME  Returns a Unicode string with the delimiters a...
#  14        REPLACE  Replace all occurrences of a substring, within...
#  15      REPLICATE  Return a string repeated a specified number of...
#  16        REVERSE    Return the reverse order of a character string.
#  17          RIGHT  Extract a given number of characters from a ch...
#  18          RTRIM  Return a new string from a specified string af...
#  19          SPACE               Returns a string of repeated spaces.
#  20            STR  Returns character data converted from numeric ...
#  21     STRING_AGG  Concatenate rows of strings with a specified s...
#  22  STRING_ESCAPE  Escape special characters in a string and retu...
#  23   STRING_SPLIT  A table-valued function that splits a string i...
#  24          STUFF  Delete a part of a string and then insert anot...
#  25      SUBSTRING  Extract a substring within a string starting f...
#  26      TRANSLATE  Replace several single-characters, one-to-one ...
#  27           TRIM  Return a new string from a specified string af...
#  28        UNICODE  Returns the integer value, as defined by the U...
#  29          UPPER                      Convert a string to UPPERCASE]

# %%
len(dfs) # the **read_html** just return one object
# Out:
# 1

# %%
df = dfs[0]
df
# Out:
#          Function                                        Description
# 0           ASCII        Return the ASCII code value of a character.
# 1            CHAR                   Convert an ASCII to a character.
# 2       CHARINDEX  Search for a substring inside a string startin...
# 3          CONCAT          Join two or more strings into one string.
# 4       CONCAT_WS  Concatenate multiple strings with a separator ...
# 5      DIFFERENCE       Compare the SOUNDEX() values of two strings.
# 6         SOUNDEX  Return a four-character (SOUNDEX) code of a st...
# 7            LEFT  Extract a given a number of characters from a ...
# 8             LEN  Return a number of character of a character st...
# 9           LOWER                     Convert a string to lowercase.
# 10          LTRIM  Return a new string from a specified string af...
# 11          NCHAR  Return the Unicode character with the specifie...
# 12       PATINDEX  Returns the starting position of the first occ...
# 13      QUOTENAME  Returns a Unicode string with the delimiters a...
# 14        REPLACE  Replace all occurrences of a substring, within...
# 15      REPLICATE  Return a string repeated a specified number of...
# 16        REVERSE    Return the reverse order of a character string.
# 17          RIGHT  Extract a given number of characters from a ch...
# 18          RTRIM  Return a new string from a specified string af...
# 19          SPACE               Returns a string of repeated spaces.
# 20            STR  Returns character data converted from numeric ...
# 21     STRING_AGG  Concatenate rows of strings with a specified s...
# 22  STRING_ESCAPE  Escape special characters in a string and retu...
# 23   STRING_SPLIT  A table-valued function that splits a string i...
# 24          STUFF  Delete a part of a string and then insert anot...
# 25      SUBSTRING  Extract a substring within a string starting f...
# 26      TRANSLATE  Replace several single-characters, one-to-one ...
# 27           TRIM  Return a new string from a specified string af...
# 28        UNICODE  Returns the integer value, as defined by the U...
# 29          UPPER                      Convert a string to UPPERCASE

# %% [markdown]
# The content of the DataFrame similar to HTML raw data, so we can apply any DataFrame operation to it.

# %%
df.shape, df.size, df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Function     30 non-null     object
#  1   Description  30 non-null     object
# dtypes: object(2)
# memory usage: 608.0+ bytes
# ((30, 2), 60, None)

# %%
df.loc[df['Function'] == 'CHAR']
# Out:
#   Function                       Description
# 1     CHAR  Convert an ASCII to a character.

# %% [markdown]
# ### Defining header

# %% [markdown]
# Pandas will automatically find he header to use thanks to the tags
#
# But in many cases, we'll find wrong or incomplete tables that make the **read_html** method parse the tables in a wrong way without the proper headers.
#
# To fix them, we use header attribute.

# %%
html_string1 = '''
        <table>
            <tr>
                <td>Function</td>
                <td>Description</td>
            </tr>
            <tr>
                <td>ASCII</td>
                <td>Return the ASCII code value of a character.</td>
            </tr>
            <tr>
                <td>CHAR</td>
                <td>Convert an ASCII to a character.</td>
            </tr>
            <tr>
                <td>CHARINDEX</td>
                <td>Search for a substring inside a string starting from a specified location and return the position of the substring.</td>
            </tr>
            <tr>
                <td>CONCAT</td>
                <td>Join two or more strings into one string.</td>
            </tr>
            <tr>
                <td>CONCAT_WS</td>
                <td>Concatenate multiple strings with a separator into a single string.</td>
            </tr>
            </table>
            '''

# %%
pd.read_html(html_string1)[0]
# Out:
#            0                                                  1
# 0   Function                                        Description
# 1      ASCII        Return the ASCII code value of a character.
# 2       CHAR                   Convert an ASCII to a character.
# 3  CHARINDEX  Search for a substring inside a string startin...
# 4     CONCAT          Join two or more strings into one string.
# 5  CONCAT_WS  Concatenate multiple strings with a separator ...

# %%
pd.read_html(html_string1, header=0)[0]
# Out:
#     Function                                        Description
# 0      ASCII        Return the ASCII code value of a character.
# 1       CHAR                   Convert an ASCII to a character.
# 2  CHARINDEX  Search for a substring inside a string startin...
# 3     CONCAT          Join two or more strings into one string.
# 4  CONCAT_WS  Concatenate multiple strings with a separator ...

# %% [markdown]
# ## Parsing HTML tables from the web

# %% [markdown]
# Now, we try to parse HTML tables from the url by call the **read_html** method with an url parameter.

# %%
html_url = 'https://panchatantra.kar.nic.in/stat/Default.aspx'

# %%
statistic_table = pd.read_html(html_url, match= 'Issuance of Building Permission - Commercial',header=0)

# %%
len(statistic_table)
# Out:
# 2

# %%
statistic_1 = statistic_table[1]
statistic_1
# Out:
#        District Name  No Of Panchayats  \
# 0          BAGALKOTE               196
# 1          BENGALURU                88
# 2    BENGALURU RURAL                 1
# 3    BENGALURU RURAL               100
# 4           BELAGAVI                 1
# 5           BELAGAVI               497
# 6            BALLARI               200
# 7            BALLARI                37
# 8              BIDAR               185
# 9         VIJAYAPURA               211
# 10   CHAMARAJANAGARA               130
# 11    CHIKKAMAGALURU               226
# 12       CHITRADURGA               189
# 13  DAKSHINA KANNADA               223
# 14        DAVANAGERE               196
# 15           DHARWAR               144
# 16             GADAG               122
# 17        KALABURAGI               261
# 18            HASSAN               267
# 19            HAVERI               223
# 20            KODAGU               104
# 21             KOLAR               154
# 22            KOPPAL               153
# 23            MANDYA               233
# 24            MYSURU               257
# 25           RAICHUR               178
# 26        SHIVAMOGGA               266
# 27          TUMAKURU               330
# 28             UDUPI               155
# 29    UTTARA KANNADA               229
# 30   CHIKKABALLAPURA               157
# 31        RAMANAGARA               126
# 32            YADGIR               122
# 33             TOTAL              5961
#
#     Issuance of Building Permission - Commercial (New/Addl/Mod)  \
# 0                                                  79
# 1                                                 164
# 2                                                   0
# 3                                                 286
# 4                                                   0
# 5                                                 267
# 6                                                 185
# 7                                                   5
# 8                                                 103
# 9                                                 226
# 10                                                152
# 11                                               2267
# 12                                                167
# 13                                               8303
# 14                                                457
# 15                                                223
# 16                                                265
# 17                                                259
# 18                                               1279
# 19                                                466
# 20                                                260
# 21                                                134
# 22                                                276
# 23                                                665
# 24                                                632
# 25                                                 27
# 26                                                511
# 27                                                840
# 28                                               6846
# 29                                                653
# 30                                                124
# 31                                                361
# 32                                                 19
# 33                                              26501
#
#     Issuance of Building Permission - Residential (New/Addl/Mod)  \
# 0                                                2997
# 1                                                2137
# 2                                                   0
# 3                                                5200
# 4                                                   0
# 5                                                4443
# 6                                                3118
# 7                                                 692
# 8                                                3438
# 9                                                4398
# 10                                               2652
# 11                                              10641
# 12                                               3511
# 13                                              37582
# 14                                               4702
# 15                                               3017
# 16                                               7573
# 17                                               1796
# 18                                               8600
# 19                                               8006
# 20                                               3293
# 21                                              12183
# 22                                               2820
# 23                                               6612
# 24                                               8189
# 25                                                371
# 26                                               7164
# 27                                               9847
# 28                                              40866
# 29                                              10229
# 30                                               6143
# 31                                               3763
# 32                                                210
# 33                                             226193
#
#     Issuance of Alteration to Assessment List  \
# 0                                        4412
# 1                                      114809
# 2                                           0
# 3                                       30446
# 4                                           0
# 5                                       15122
# 6                                        4087
# 7                                        1071
# 8                                        4960
# 9                                        7240
# 10                                       9465
# 11                                      13514
# 12                                      11771
# 13                                      13438
# 14                                       7261
# 15                                       2734
# 16                                       2454
# 17                                       1396
# 18                                      33987
# 19                                      30119
# 20                                        372
# 21                                      34811
# 22                                      11531
# 23                                      43727
# 24                                      28451
# 25                                        518
# 26                                      17511
# 27                                      43281
# 28                                      17918
# 29                                       6325
# 30                                      29302
# 31                                      21990
# 32                                        679
# 33                                     564702
#
#     Copy of Demand/ Assessment List (Existing)  \
# 0                                           88
# 1                                          261
# 2                                            0
# 3                                         1304
# 4                                            0
# 5                                           64
# 6                                           69
# 7                                            8
# 8                                           34
# 9                                           45
# 10                                          97
# 11                                         889
# 12                                          86
# 13                                          98
# 14                                         231
# 15                                          14
# 16                                           1
# 17                                          25
# 18                                        3640
# 19                                         215
# 20                                          12
# 21                                         499
# 22                                         498
# 23                                         790
# 24                                         677
# 25                                          10
# 26                                        1289
# 27                                        2036
# 28                                          23
# 29                                          74
# 30                                         445
# 31                                         948
# 32                                           1
# 33                                       14471
#
#     Application to waive off property tax  \
# 0                                       1
# 1                                       5
# 2                                       0
# 3                                       8
# 4                                       0
# 5                                      15
# 6                                      13
# 7                                       1
# 8                                      18
# 9                                       6
# 10                                      3
# 11                                      7
# 12                                      9
# 13                                      9
# 14                                     11
# 15                                      3
# 16                                      3
# 17                                      8
# 18                                     29
# 19                                     14
# 20                                      1
# 21                                     13
# 22                                      8
# 23                                      8
# 24                                      6
# 25                                      6
# 26                                      7
# 27                                     32
# 28                                      1
# 29                                      0
# 30                                      5
# 31                                      7
# 32                                      3
# 33                                    260
#
#     Issuance for Building Completion Certificate  \
# 0                                              2
# 1                                              3
# 2                                              0
# 3                                              9
# 4                                              0
# 5                                              6
# 6                                              5
# 7                                              1
# 8                                              3
# 9                                              6
# 10                                             1
# 11                                            11
# 12                                             5
# 13                                           283
# 14                                             5
# 15                                            14
# 16                                            26
# 17                                             2
# 18                                            15
# 19                                            23
# 20                                            14
# 21                                             3
# 22                                             9
# 23                                            10
# 24                                            11
# 25                                             1
# 26                                            15
# 27                                             5
# 28                                            72
# 29                                            19
# 30                                             2
# 31                                             6
# 32                                             3
# 33                                           590
#
#     Application for new water connection  Intimation of digging of borewell  \
# 0                                     10                                  2
# 1                                     63                                  4
# 2                                      0                                  0
# 3                                    122                                  7
# 4                                      0                                  0
# 5                                     87                                 14
# 6                                     63                                  7
# 7                                      2                                  0
# 8                                     40                                  4
# 9                                     38                                  9
# 10                                   180                                  0
# 11                                   493                                155
# 12                                    41                                  5
# 13                                  1605                                447
# 14                                   171                                 31
# 15                                   120                                  3
# 16                                    51                                  0
# 17                                    35                                  6
# 18                                   385                                358
# 19                                   204                                 94
# 20                                   131                                 32
# 21                                    61                                  6
# 22                                   131                                  4
# 23                                   358                                 87
# 24                                   335                                  3
# 25                                    39                                  8
# 26                                   320                                 73
# 27                                   270                                 44
# 28                                   588                                174
# 29                                    91                                 10
# 30                                    49                                 34
# 31                                   122                                 10
# 32                                    29                                  1
# 33                                  6234                               1632
#
#     Application for Disconnecting Water Connection  \
# 0                                                7
# 1                                                6
# 2                                                0
# 3                                                7
# 4                                                0
# 5                                               28
# 6                                               14
# 7                                                1
# 8                                               43
# 9                                                7
# 10                                               8
# 11                                              42
# 12                                               5
# 13                                              94
# 14                                              13
# 15                                               6
# 16                                              13
# 17                                              42
# 18                                              23
# 19                                              11
# 20                                              13
# 21                                               3
# 22                                              19
# 23                                              22
# 24                                              13
# 25                                               5
# 26                                              17
# 27                                              20
# 28                                               6
# 29                                               4
# 30                                               7
# 31                                               4
# 32                                              12
# 33                                             515
#
#     Intimation to closure of Bore wells
# 0                                     0
# 1                                     1
# 2                                     0
# 3                                     1
# 4                                     0
# 5                                     1
# 6                                     4
# 7                                     0
# 8                                     3
# 9                                     3
# 10                                    0
# 11                                   38
# 12                                    1
# 13                                   30
# 14                                    2
# 15                                    0
# 16                                    0
# 17                                    1
# 18                                   16
# 19                                    3
# 20                                    2
# 21                                    1
# 22                                    3
# 23                                   13
# 24                                    3
# 25                                    1
# 26                                   14
# 27                                    5
# 28                                   50
# 29                                    1
# 30                                    2
# 31                                    0
# 32                                    2
# 33                                  201

# %% [markdown]
# ### Complex example

# %% [markdown]
# We can also use **requests** module to get HTML code from an url to parse into DataFrame objects if we look into the given url with multiple tables and we want to keep the table with information about ech character.

# %%
import requests
html_url = 'https://en.wikipedia.org/wiki/The_Simpsons'

# %%
r = requests.get(html_url)

# %%
statistic_tables = pd.read_html(r.text, header = 0)

# %%
len(statistic_tables)
# Out:
# 31

# %%
table_1 = statistic_tables[1]

# %%
table_1.head()
# Out:
#    Season Season.1  No. ofepisodes    Originally aired Originally aired.1  \
# 0  Season   Season  No. ofepisodes     Season premiere      Season finale
# 1  Season   Season  No. ofepisodes     Season premiere      Season finale
# 2       1  1989–90              13   December 17, 1989       May 13, 1990
# 3       2  1990–91              22    October 11, 1990      July 11, 1991
# 4       3  1991–92              24  September 19, 1991    August 27, 1992
#
#   Originally aired.2                 Viewership          Viewership.1  \
# 0     Time slot (ET)  Avg. viewers(in millions)  Most watched episode
# 1     Time slot (ET)  Avg. viewers(in millions)     Viewers(millions)
# 2     Sunday 8:30 pm                       27.8                  33.5
# 3   Thursday 8:00 pm                       24.4                  33.6
# 4   Thursday 8:00 pm                       21.8                  25.5
#
#               Viewership.2
# 0     Most watched episode
# 1            Episode title
# 2  "Life on the Fast Lane"
# 3       "Bart Gets an 'F'"
# 4          "Colonel Homer"

# %% [markdown]
# Quick clean on the table, remove extra header rows and set Season as index

# %%
table_1.drop([0,1], inplace = True)

# %%
table_1.head(2)
# Out:
#   Season Season.1 No. ofepisodes   Originally aired Originally aired.1  \
# 2      1  1989–90             13  December 17, 1989       May 13, 1990
# 3      2  1990–91             22   October 11, 1990      July 11, 1991
#
#   Originally aired.2 Viewership Viewership.1             Viewership.2
# 2     Sunday 8:30 pm       27.8         33.5  "Life on the Fast Lane"
# 3   Thursday 8:00 pm       24.4         33.6       "Bart Gets an 'F'"

# %%
table_1.set_index('Season', inplace= True)

# %%
table_1['No. ofepisodes'].unique()
# Out:
# array(['13', '22', '24', '25', '23', '21', '20'], dtype=object)

# %%
table_1 = table_1.loc[table_1['']
