# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'Name' : ['Braund, Mr. Owen Harris',
             'Allen, Mr.William Henry',
             'Bonnell, Mis.Elizabeth'],
    'Age' : [22, 35, 58],
    'Sex' : ['Male', 'Male', 'Female']
})
df
# Out:
#                       Name  Age     Sex
# 0  Braund, Mr. Owen Harris   22    Male
# 1  Allen, Mr.William Henry   35    Male
# 2   Bonnell, Mis.Elizabeth   58  Female

# %%
df = pd.read_excel('cryptos_1.xlsx')
df
# Out:
#               CloseTime  OpenPrice  HighPrice  LowPrice  ClosePrice  \
# 0   2021-09-18 02:00:00   47374.00   47687.89  47345.60    47623.81
# 1   2021-09-18 03:00:00   47642.50   47702.97  47520.00    47666.92
# 2   2021-09-18 04:00:00   47692.63   48000.00  47676.75    47944.80
# 3   2021-09-18 05:00:00   47944.80   48356.55  47933.83    48349.16
# 4   2021-09-18 06:00:00   48349.25   48783.10  48302.84    48681.01
# ..                  ...        ...        ...       ...         ...
# 157 2021-09-24 15:00:00   41871.53   42718.20  41791.60    42474.82
# 158 2021-09-24 16:00:00   42483.44   42496.26  41658.29    41996.05
# 159 2021-09-24 17:00:00   41969.71   42387.48  41888.26    42221.31
# 160 2021-09-24 18:00:00   42221.31   42221.31  41780.00    41994.61
# 161 2021-09-24 19:00:00   42025.61   42200.80  41970.00    42144.78
#
#          Volume            NA
# 0     41.199507  1.958788e+06
# 1     80.349023  3.825109e+06
# 2     71.598084  3.425289e+06
# ...

# %%
df = pd.read_csv('btc_market_price.csv', names = ['Time', 'Value'])
df
# Out:
#                     Time     Value
# 0    2021-09-18 02:00:00     47374
# 1    2021-09-18 03:00:00         _
# 2    2021-09-18 04:00:00         ?
# 3    2021-09-18 05:00:00       NaN
# 4    2021-09-18 06:00:00       NaN
# ..                   ...       ...
# 157  2021-09-24 15:00:00  41871.53
# 158  2021-09-24 16:00:00  42483.44
# 159  2021-09-24 17:00:00  41969.71
# 160  2021-09-24 18:00:00  42221.31
# 161  2021-09-24 19:00:00  42025.61
#
# [162 rows x 2 columns]

# %%
a = df.loc[df['Value'].isin(['47374'])]
a
# Out:
#                   Time  Value
# 0  2021-09-18 02:00:00  47374

# %%
a = df[(df['Value']== '47374') | (df['Value'] == '41871.53')]
a
# Out:
#                     Time     Value
# 0    2021-09-18 02:00:00     47374
# 157  2021-09-24 15:00:00  41871.53

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Book1.csv', index_col = 0, parse_dates = True)

# %%
df.head(4)
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0

# %%
df.plot()

# %%
df.iloc[:,1].plot()

# %%
df.plot.scatter(x ='station_london', y='station_paris', alpha=0.5)

# %%
a = [method_name
for method_name in dir(df.plot)
    if not method_name.startswith("_")]
a
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
df.plot.area()

# %%
df.plot(figsize =(12, 5), subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000211EE86AE08>,
# ...
#       dtype=object)

# %%
fig, axs = plt.subplots(figsize = (12, 4))
df.plot.area(ax = axs)
axs.set_ylabel('NO$_2$ concentration')
# Out:
# Text(0, 0.5, 'NO$_2$ concentration')

# %%
df_renamed = df.rename(columns = {'station_antwerp':'BETR801',
                    'station_paris' : 'FT04014',
                    'station_london' : 'London Westminster'})
df_renamed
# Out:
#                      BETR801  FT04014  London Westminster
# datetime
# 2019-05-07 02:00:00      NaN      NaN                23.0
# 2019-05-07 03:00:00     50.5     25.0                19.0
# 2019-05-07 04:00:00     45.0     27.7                19.0
# 2019-05-07 05:00:00      NaN     50.4                16.0
# 2019-05-07 06:00:00      NaN     61.9                 NaN
# ...                      ...      ...                 ...
# 2019-06-20 22:00:00      NaN     21.4                 NaN
# 2019-06-20 23:00:00      NaN     24.9                 NaN
# 2019-06-21 00:00:00      NaN     26.5                 NaN
# 2019-06-21 01:00:00      NaN     21.8                 NaN
# 2019-06-21 02:00:00      NaN     20.0                 NaN
#
# [1035 rows x 3 columns]

# %%
df_renamed = df_renamed.rename(columns = str.lower)

# %%
df_renamed
# Out:
#                      betr801  ft04014  london westminster
# datetime
# 2019-05-07 02:00:00      NaN      NaN                23.0
# 2019-05-07 03:00:00     50.5     25.0                19.0
# 2019-05-07 04:00:00     45.0     27.7                19.0
# 2019-05-07 05:00:00      NaN     50.4                16.0
# 2019-05-07 06:00:00      NaN     61.9                 NaN
# ...                      ...      ...                 ...
# 2019-06-20 22:00:00      NaN     21.4                 NaN
# 2019-06-20 23:00:00      NaN     24.9                 NaN
# 2019-06-21 00:00:00      NaN     26.5                 NaN
# 2019-06-21 01:00:00      NaN     21.8                 NaN
# 2019-06-21 02:00:00      NaN     20.0                 NaN
#
# [1035 rows x 3 columns]

# %%
df.agg({'station_paris' : ['min', 'max', 'median', 'skew'],
       'station_london' : ['min', 'max', 'median', 'std', 'mean']})
# Out:
#         station_paris  station_london
# max         97.000000       97.000000
# mean              NaN       24.777090
# median      24.150000       25.000000
# min          0.000000        0.000000
# skew         1.161128             NaN
# std               NaN       11.214377

# %%
df = pd.read_csv('btc_market_price1.csv', parse_dates = True)
df
# Out:
#             timestamp     price
# 0    2021-09-18 00:00  47374.00
# 1    2021-09-19 00:00  47642.50
# 2    2021-09-20 00:00  47692.63
# 3    2021-09-21 00:00  47944.80
# 4    2021-09-22 00:00  48349.25
# ..                ...       ...
# 157  2022-02-22 00:00  41871.53
# 158  2022-02-23 00:00  42483.44
# 159  2022-02-24 00:00  41969.71
# 160  2022-02-25 00:00  42221.31
# 161  2022-02-26 00:00  42025.61
#
# [162 rows x 2 columns]

# %%
df = pd.read_csv('titanic.txt',delimiter = ',', header = 0)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['Age', 'Sex']].groupby('Sex').mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
df.groupby('Sex').mean()
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
df.groupby('Sex')[['Age', 'Survived']].mean()
# Out:
#               Age  Survived
# Sex
# female  27.915709  0.742038
# male    30.726645  0.188908

# %%
df[['Age', 'Survived', 'Sex']].groupby('Sex').mean()
# Out:
#               Age  Survived
# Sex
# female  27.915709  0.742038
# male    30.726645  0.188908

# %%
import pandas as pd

# %%
titanic = pd.read_csv('titanic.txt', header = 0, parse_dates = True)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
titanic.groupby('Pclass').count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491

# %%
titanic.sort_values(by = ['Pclass', 'Age'], ascending = False)
# Out:
#      PassengerId  Survived  Pclass  \
# 851          852         0       3
# 116          117         0       3
# 280          281         0       3
# 483          484         1       3
# 326          327         0       3
# ..           ...       ...     ...
# 766          767         0       1
# 793          794         0       1
# 815          816         0       1
# 839          840         1       1
# 849          850         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 851                           Svensson, Mr. Johan    male  74.0      0      0
# 116                          Connors, Mr. Patrick    male  70.5      0      0
# 280                              Duane, Mr. Frank    male  65.0      0      0
# 483                        Turkula, Mrs. (Hedwig)  female  63.0      0      0
# 326                     Nysveen, Mr. Johan Hansen    male  61.0      0      0
# ...

# %%
df = pd.read_csv('air_quality_long.txt', header =0, index_col ='date.utc', parse_dates = True)
df
# Out:
#                                 city country            location parameter  \
# date.utc
# 2019-06-18 06:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 08:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 07:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 06:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 05:00:00+00:00  Antwerpen      BE             BETR801      pm25
# ...                              ...     ...                 ...       ...
# 2019-04-09 06:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 05:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 04:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 03:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 02:00:00+00:00     London      GB  London Westminster       no2
#
#                            value   unit
# date.utc
# ...

# %%
no2 = df[df['parameter'] == 'no2']
no2
# Out:
#                              city country            location parameter  \
# date.utc
# 2019-06-21 00:00:00+00:00   Paris      FR             FR04014       no2
# 2019-06-20 23:00:00+00:00   Paris      FR             FR04014       no2
# 2019-06-20 22:00:00+00:00   Paris      FR             FR04014       no2
# 2019-06-20 21:00:00+00:00   Paris      FR             FR04014       no2
# 2019-06-20 20:00:00+00:00   Paris      FR             FR04014       no2
# ...                           ...     ...                 ...       ...
# 2019-04-09 06:00:00+00:00  London      GB  London Westminster       no2
# 2019-04-09 05:00:00+00:00  London      GB  London Westminster       no2
# 2019-04-09 04:00:00+00:00  London      GB  London Westminster       no2
# 2019-04-09 03:00:00+00:00  London      GB  London Westminster       no2
# 2019-04-09 02:00:00+00:00  London      GB  London Westminster       no2
#
#                            value   unit
# date.utc
# 2019-06-21 00:00:00+00:00   20.0  µg/m³
# ...

# %%
no2_subset = no2.sort_index().groupby(['location']).head(2)
no2_subset
# Out:
#                                 city country            location parameter  \
# date.utc
# 2019-04-09 01:00:00+00:00  Antwerpen      BE             BETR801       no2
# 2019-04-09 01:00:00+00:00      Paris      FR             FR04014       no2
# 2019-04-09 02:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 02:00:00+00:00  Antwerpen      BE             BETR801       no2
# 2019-04-09 02:00:00+00:00      Paris      FR             FR04014       no2
# 2019-04-09 03:00:00+00:00     London      GB  London Westminster       no2
#
#                            value   unit
# date.utc
# 2019-04-09 01:00:00+00:00   22.5  µg/m³
# 2019-04-09 01:00:00+00:00   24.4  µg/m³
# 2019-04-09 02:00:00+00:00   67.0  µg/m³
# 2019-04-09 02:00:00+00:00   53.5  µg/m³
# 2019-04-09 02:00:00+00:00   27.4  µg/m³
# 2019-04-09 03:00:00+00:00   67.0  µg/m³

# %%
no2_subset.pivot(columns= 'location', values = 'value')
# Out:
# location                   BETR801  FR04014  London Westminster
# date.utc
# 2019-04-09 01:00:00+00:00     22.5     24.4                 NaN
# 2019-04-09 02:00:00+00:00     53.5     27.4                67.0
# 2019-04-09 03:00:00+00:00      NaN      NaN                67.0

# %%
df.pivot_table(values = 'value',
             index = 'location',
               columns = 'parameter',
              aggfunc = 'sum',
              margins = True)
# Out:
# parameter                no2     pm25       All
# location
# BETR801               4393.0   4101.0    8494.0
# FR04014              49231.3      NaN   49231.3
# London Westminster   47822.0  22155.0   69977.0
# All                 101446.3  26256.0  127702.3

# %%
a = df[['parameter', 'value']] 
#a.pivot(columns = 'parameter', values = 'value')
a
# Out:
#                           parameter  value
# date.utc
# 2019-06-18 06:00:00+00:00      pm25   18.0
# 2019-06-17 08:00:00+00:00      pm25    6.5
# 2019-06-17 07:00:00+00:00      pm25   18.5
# 2019-06-17 06:00:00+00:00      pm25   16.0
# 2019-06-17 05:00:00+00:00      pm25    7.5
# ...                             ...    ...
# 2019-04-09 06:00:00+00:00       no2   41.0
# 2019-04-09 05:00:00+00:00       no2   41.0
# 2019-04-09 04:00:00+00:00       no2   41.0
# 2019-04-09 03:00:00+00:00       no2   67.0
# 2019-04-09 02:00:00+00:00       no2   67.0
#
# [5272 rows x 2 columns]

# %%
df.groupby(['location', 'parameter']).mean()
# Out:
#                                   value
# location           parameter
# BETR801            no2        26.950920
#                    pm25       23.169492
# FR04014            no2        29.374284
# London Westminster no2        29.740050
#                    pm25       13.443568

# %%
b = pd.concat([a,df])
b
# Out:
#                           parameter  value    city country  \
# date.utc
# 2019-06-18 06:00:00+00:00      pm25   18.0     NaN     NaN
# 2019-06-17 08:00:00+00:00      pm25    6.5     NaN     NaN
# 2019-06-17 07:00:00+00:00      pm25   18.5     NaN     NaN
# 2019-06-17 06:00:00+00:00      pm25   16.0     NaN     NaN
# 2019-06-17 05:00:00+00:00      pm25    7.5     NaN     NaN
# ...                             ...    ...     ...     ...
# 2019-04-09 06:00:00+00:00       no2   41.0  London      GB
# 2019-04-09 05:00:00+00:00       no2   41.0  London      GB
# 2019-04-09 04:00:00+00:00       no2   41.0  London      GB
# 2019-04-09 03:00:00+00:00       no2   67.0  London      GB
# 2019-04-09 02:00:00+00:00       no2   67.0  London      GB
#
#                                      location   unit
# date.utc
# 2019-06-18 06:00:00+00:00                 NaN    NaN
# 2019-06-17 08:00:00+00:00                 NaN    NaN
# 2019-06-17 07:00:00+00:00                 NaN    NaN
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5272 entries, 2019-06-18 06:00:00+00:00 to 2019-04-09 02:00:00+00:00
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   parameter  5272 non-null   object
#  1   value      5272 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 283.6+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5272 entries, 2019-06-18 06:00:00+00:00 to 2019-04-09 02:00:00+00:00
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   city       5272 non-null   object
#  1   country    5272 non-null   object
#  2   location   5272 non-null   object
#  3   parameter  5272 non-null   object
#  4   value      5272 non-null   float64
#  5   unit       5272 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 448.3+ KB

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10544 entries, 2019-06-18 06:00:00+00:00 to 2019-04-09 02:00:00+00:00
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   parameter  10544 non-null  object
#  1   value      10544 non-null  float64
#  2   city       5272 non-null   object
#  3   country    5272 non-null   object
#  4   location   5272 non-null   object
#  5   unit       5272 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 576.6+ KB

# %%
df
# Out:
#                                 city country            location parameter  \
# date.utc
# 2019-06-18 06:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 08:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 07:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 06:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 05:00:00+00:00  Antwerpen      BE             BETR801      pm25
# ...                              ...     ...                 ...       ...
# 2019-04-09 06:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 05:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 04:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 03:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 02:00:00+00:00     London      GB  London Westminster       no2
#
#                            value   unit
# date.utc
# ...

# %%
df = pd.read_csv('air_quality_long.txt')
df
# Out:
#            city country                   date.utc            location  \
# 0     Antwerpen      BE  2019-06-18 06:00:00+00:00             BETR801
# 1     Antwerpen      BE  2019-06-17 08:00:00+00:00             BETR801
# 2     Antwerpen      BE  2019-06-17 07:00:00+00:00             BETR801
# 3     Antwerpen      BE  2019-06-17 06:00:00+00:00             BETR801
# 4     Antwerpen      BE  2019-06-17 05:00:00+00:00             BETR801
# ...         ...     ...                        ...                 ...
# 5267     London      GB  2019-04-09 06:00:00+00:00  London Westminster
# 5268     London      GB  2019-04-09 05:00:00+00:00  London Westminster
# 5269     London      GB  2019-04-09 04:00:00+00:00  London Westminster
# 5270     London      GB  2019-04-09 03:00:00+00:00  London Westminster
# 5271     London      GB  2019-04-09 02:00:00+00:00  London Westminster
#
#      parameter  value   unit
# 0         pm25   18.0  µg/m³
# 1         pm25    6.5  µg/m³
# ...

# %%
df = df.rename(columns = {'date.utc' : 'datetime'})
df.head()
# Out:
#         city country                   datetime location parameter  value  \
# 0  Antwerpen      BE  2019-06-18 06:00:00+00:00  BETR801      pm25   18.0
# 1  Antwerpen      BE  2019-06-17 08:00:00+00:00  BETR801      pm25    6.5
# 2  Antwerpen      BE  2019-06-17 07:00:00+00:00  BETR801      pm25   18.5
# 3  Antwerpen      BE  2019-06-17 06:00:00+00:00  BETR801      pm25   16.0
# 4  Antwerpen      BE  2019-06-17 05:00:00+00:00  BETR801      pm25    7.5
#
#     unit
# 0  µg/m³
# 1  µg/m³
# 2  µg/m³
# 3  µg/m³
# 4  µg/m³

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5272 entries, 0 to 5271
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   city       5272 non-null   object
#  1   country    5272 non-null   object
#  2   datetime   5272 non-null   datetime64[ns, UTC]
#  3   location   5272 non-null   object
#  4   parameter  5272 non-null   object
#  5   value      5272 non-null   float64
#  6   unit       5272 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), object(5)
# memory usage: 288.4+ KB

# %%
df['datetime'].max() - df['datetime'].min()
# Out:
# Timedelta('72 days 23:00:00')

# %%
df['month'] = df['datetime'].dt.month

# %%
df.head()
# Out:
#         city country                  datetime location parameter  value  \
# 0  Antwerpen      BE 2019-06-18 06:00:00+00:00  BETR801      pm25   18.0
# 1  Antwerpen      BE 2019-06-17 08:00:00+00:00  BETR801      pm25    6.5
# 2  Antwerpen      BE 2019-06-17 07:00:00+00:00  BETR801      pm25   18.5
# 3  Antwerpen      BE 2019-06-17 06:00:00+00:00  BETR801      pm25   16.0
# 4  Antwerpen      BE 2019-06-17 05:00:00+00:00  BETR801      pm25    7.5
#
#     unit  month
# 0  µg/m³      6
# 1  µg/m³      6
# 2  µg/m³      6
# 3  µg/m³      6
# 4  µg/m³      6

# %%
a =df.groupby([df['datetime'].dt.weekday, 'location'])['value'].mean()
a.head()
# Out:
# datetime  location
# 0         BETR801               25.065657
#           FR04014               29.495417
#           London Westminster    21.173077
# 1         BETR801               32.423077
#           FR04014               34.402381
# Name: value, dtype: float64

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(figsize = (12, 5))
a = df.groupby(df['datetime'].dt.hour)['value'].mean().plot(kind = 'bar', rot=0, ax = axs)

# %%
df
# Out:
#            city country                  datetime            location  \
# 0     Antwerpen      BE 2019-06-18 06:00:00+00:00             BETR801
# 1     Antwerpen      BE 2019-06-17 08:00:00+00:00             BETR801
# 2     Antwerpen      BE 2019-06-17 07:00:00+00:00             BETR801
# 3     Antwerpen      BE 2019-06-17 06:00:00+00:00             BETR801
# 4     Antwerpen      BE 2019-06-17 05:00:00+00:00             BETR801
# ...         ...     ...                       ...                 ...
# 5267     London      GB 2019-04-09 06:00:00+00:00  London Westminster
# 5268     London      GB 2019-04-09 05:00:00+00:00  London Westminster
# 5269     London      GB 2019-04-09 04:00:00+00:00  London Westminster
# 5270     London      GB 2019-04-09 03:00:00+00:00  London Westminster
# 5271     London      GB 2019-04-09 02:00:00+00:00  London Westminster
#
#      parameter  value   unit  month
# 0         pm25   18.0  µg/m³      6
# 1         pm25    6.5  µg/m³      6
# ...

# %%
# df['datetime'].unique()
df.drop_duplicates(inplace = True)
df.reset_index()
# Out:
#       index       city country                  datetime            location  \
# 0         0  Antwerpen      BE 2019-06-18 06:00:00+00:00             BETR801
# 1         1  Antwerpen      BE 2019-06-17 08:00:00+00:00             BETR801
# 2         2  Antwerpen      BE 2019-06-17 07:00:00+00:00             BETR801
# 3         3  Antwerpen      BE 2019-06-17 06:00:00+00:00             BETR801
# 4         4  Antwerpen      BE 2019-06-17 05:00:00+00:00             BETR801
# ...     ...        ...     ...                       ...                 ...
# 5267   5267     London      GB 2019-04-09 06:00:00+00:00  London Westminster
# 5268   5268     London      GB 2019-04-09 05:00:00+00:00  London Westminster
# 5269   5269     London      GB 2019-04-09 04:00:00+00:00  London Westminster
# 5270   5270     London      GB 2019-04-09 03:00:00+00:00  London Westminster
# 5271   5271     London      GB 2019-04-09 02:00:00+00:00  London Westminster
#
#      parameter  value   unit
# ...

# %%
df.set_index('datetime', inplace = True)
df
# Out:
#                                 city country            location parameter  \
# datetime
# 2019-06-18 06:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 08:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 07:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 06:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 05:00:00+00:00  Antwerpen      BE             BETR801      pm25
# ...                              ...     ...                 ...       ...
# 2019-04-09 06:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 05:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 04:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 03:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 02:00:00+00:00     London      GB  London Westminster       no2
#
#                            value   unit
# datetime
# ...

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#                       datetime       city country            location  \
# 0    2019-06-18 06:00:00+00:00  Antwerpen      BE             BETR801
# 1    2019-06-17 08:00:00+00:00  Antwerpen      BE             BETR801
# 2    2019-06-17 07:00:00+00:00  Antwerpen      BE             BETR801
# 3    2019-06-17 06:00:00+00:00  Antwerpen      BE             BETR801
# 4    2019-06-17 05:00:00+00:00  Antwerpen      BE             BETR801
# ...                        ...        ...     ...                 ...
# 5267 2019-04-09 06:00:00+00:00     London      GB  London Westminster
# 5268 2019-04-09 05:00:00+00:00     London      GB  London Westminster
# 5269 2019-04-09 04:00:00+00:00     London      GB  London Westminster
# 5270 2019-04-09 03:00:00+00:00     London      GB  London Westminster
# 5271 2019-04-09 02:00:00+00:00     London      GB  London Westminster
#
#      parameter  value   unit
# 0         pm25   18.0  µg/m³
# 1         pm25    6.5  µg/m³
# 2         pm25   18.5  µg/m³
# ...

# %%
# no_2 = df[df['parameter'] == 'no2']
# no_2.reset_index(inplace= True)
no_2.sort_values('datetime')
# del no_2['index']
# Out:
#                       datetime       city country            location  \
# 1838 2019-04-09 01:00:00+00:00  Antwerpen      BE             BETR801
# 1675 2019-04-09 01:00:00+00:00      Paris      FR             FR04014
# 3446 2019-04-09 02:00:00+00:00     London      GB  London Westminster
# 1837 2019-04-09 02:00:00+00:00  Antwerpen      BE             BETR801
# 1674 2019-04-09 02:00:00+00:00      Paris      FR             FR04014
# ...                        ...        ...     ...                 ...
# 4    2019-06-20 20:00:00+00:00      Paris      FR             FR04014
# 3    2019-06-20 21:00:00+00:00      Paris      FR             FR04014
# 2    2019-06-20 22:00:00+00:00      Paris      FR             FR04014
# 1    2019-06-20 23:00:00+00:00      Paris      FR             FR04014
# 0    2019-06-21 00:00:00+00:00      Paris      FR             FR04014
#
#      parameter  value   unit
# 1838       no2   22.5  µg/m³
# 1675       no2   24.4  µg/m³
# 3446       no2   67.0  µg/m³
# ...

# %%
no_2 = pd.read_csv('no2_long.txt')
no_2.sort_values('date.utc')
# Out:
#            city country                   date.utc            location  \
# 2067     London      GB  2019-05-07 01:00:00+00:00  London Westminster
# 1098  Antwerpen      BE  2019-05-07 01:00:00+00:00             BETR801
# 1003      Paris      FR  2019-05-07 01:00:00+00:00             FR04014
# 1002      Paris      FR  2019-05-07 02:00:00+00:00             FR04014
# 2066     London      GB  2019-05-07 02:00:00+00:00  London Westminster
# ...         ...     ...                        ...                 ...
# 4         Paris      FR  2019-06-20 20:00:00+00:00             FR04014
# 3         Paris      FR  2019-06-20 21:00:00+00:00             FR04014
# 2         Paris      FR  2019-06-20 22:00:00+00:00             FR04014
# 1         Paris      FR  2019-06-20 23:00:00+00:00             FR04014
# 0         Paris      FR  2019-06-21 00:00:00+00:00             FR04014
#
#      parameter  value   unit
# 2067       no2   23.0  µg/m³
# 1098       no2   50.5  µg/m³
# ...

# %%
# no_2['date.utc'] = pd.to_datetime(no_2['date.utc'])
# no_2.info()
no2_pivot = no_2.pivot(index = 'date.utc', columns = 'location', values = 'value')
no2_pivot
# Out:
# location                   BETR801  FR04014  London Westminster
# date.utc
# 2019-05-07 01:00:00+00:00     50.5     25.0                23.0
# 2019-05-07 02:00:00+00:00     45.0     27.7                19.0
# 2019-05-07 03:00:00+00:00      NaN     50.4                19.0
# 2019-05-07 04:00:00+00:00      NaN     61.9                16.0
# 2019-05-07 05:00:00+00:00      NaN     72.4                 NaN
# ...                            ...      ...                 ...
# 2019-06-20 20:00:00+00:00      NaN     21.4                 NaN
# 2019-06-20 21:00:00+00:00      NaN     24.9                 NaN
# 2019-06-20 22:00:00+00:00      NaN     26.5                 NaN
# 2019-06-20 23:00:00+00:00      NaN     21.8                 NaN
# 2019-06-21 00:00:00+00:00      NaN     20.0                 NaN
#
# [1033 rows x 3 columns]

# %%
# air_quality_long = pd.read_csv('air_quality_long.txt')
# air_quality_long['date.utc'] = pd.to_datetime(air_quality_long['date.utc'])
# air_quality_long.duplicated().value_counts()
air_quality_long.head(3501).pivot_table(index = 'date.utc', columns = ['location', 'parameter'], values = 'value')
# air_quality_long.head(3501).pivot(index = ['date.utc','location'], columns = 'parameter', values = 'value')
# air_quality_long.groupby(['location', 'parameter'])['value'].mean()
# air_quality_long.sort_values(['date.utc', 'location', 'parameter', 'value'])
# air_quality_long.info()
# Out:
# location                  BETR801 FR04014 London Westminster
# parameter                    pm25     no2               pm25
# date.utc
# 2019-04-09 01:00:00+00:00    76.0    24.4                NaN
# 2019-04-09 02:00:00+00:00    91.5    27.4               42.0
# 2019-04-09 03:00:00+00:00    99.0    34.2               42.0
# 2019-04-09 04:00:00+00:00    83.5    48.5               43.0
# 2019-04-09 05:00:00+00:00    68.0    59.5               44.0
# ...                           ...     ...                ...
# 2019-06-20 20:00:00+00:00     NaN    21.4                8.0
# 2019-06-20 21:00:00+00:00     NaN    24.9                8.0
# 2019-06-20 22:00:00+00:00     NaN    26.5                7.0
# 2019-06-20 23:00:00+00:00     NaN    21.8                7.0
# 2019-06-21 00:00:00+00:00     NaN    20.0                7.0
#
# [1713 rows x 3 columns]

# %%
# air_quality_long.head(2)
air_quality_long.iloc[3502]
# Out:
# city                         Antwerpen
# country                             BE
# date.utc     2019-06-17 07:00:00+00:00
# location                       BETR801
# parameter                          no2
# value                               45
# unit                             µg/m³
# Name: 3502, dtype: object

# %%
air_quality_long.loc[air_quality_long['date.utc']=='2019-06-17 07:00:00+00:00']
# Out:
#            city country                  date.utc            location  \
# 2     Antwerpen      BE 2019-06-17 07:00:00+00:00             BETR801
# 221      London      GB 2019-06-17 07:00:00+00:00  London Westminster
# 1868      Paris      FR 2019-06-17 07:00:00+00:00             FR04014
# 3502  Antwerpen      BE 2019-06-17 07:00:00+00:00             BETR801
# 3668     London      GB 2019-06-17 07:00:00+00:00  London Westminster
#
#      parameter  value   unit
# 2         pm25   18.5  µg/m³
# 221       pm25    6.0  µg/m³
# 1868       no2   54.4  µg/m³
# 3502       no2   45.0  µg/m³
# 3668       no2   13.0  µg/m³

# %%
no2_pivot['2019-05-20':'2019-05-21'].plot()

# %%
# no2_pivot['date.utc'].max()
no2_pivot.sort_index()
# Out:
# location                   BETR801  FR04014  London Westminster
# date.utc
# 2019-05-07 01:00:00+00:00     50.5     25.0                23.0
# 2019-05-07 02:00:00+00:00     45.0     27.7                19.0
# 2019-05-07 03:00:00+00:00      NaN     50.4                19.0
# 2019-05-07 04:00:00+00:00      NaN     61.9                16.0
# 2019-05-07 05:00:00+00:00      NaN     72.4                 NaN
# ...                            ...      ...                 ...
# 2019-06-20 20:00:00+00:00      NaN     21.4                 NaN
# 2019-06-20 21:00:00+00:00      NaN     24.9                 NaN
# 2019-06-20 22:00:00+00:00      NaN     26.5                 NaN
# 2019-06-20 23:00:00+00:00      NaN     21.8                 NaN
# 2019-06-21 00:00:00+00:00      NaN     20.0                 NaN
#
# [1033 rows x 3 columns]

# %%
monthly_max = no2_pivot.resample('M').sum()
monthly_max
# Out:
# location                   BETR801  FR04014  London Westminster
# date.utc
# 2019-05-31 00:00:00+00:00   1874.5  16521.8             16529.0
# 2019-06-30 00:00:00+00:00    574.5  11329.7              7480.0

# %%
monthly_max.index.freq

# %%
no2_pivot.resample('D').mean().plot(style = '-o', figsize = (12,4))

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic['surname'] = titanic['Name'].str.split(',')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic['surname'].str.get(0)
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: surname, Length: 891, dtype: object

# %%
titanic['Name'].str.split(',').str.get(0).head(2)
# Out:
# 0     Braund
# 1    Cumings
# Name: Name, dtype: object

# %%
titanic['Name'].str.contains('Countess')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Name, Length: 891, dtype: bool

# %%
titanic[titanic['Name'].str.contains('Countess')]
# Out:
#      PassengerId  Survived  Pclass  \
# 759          760         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0      0
#
#      Parch  Ticket  Fare Cabin Embarked  \
# 759      0  110152  86.5   B77        S
#
#                                                surname
# 759  [Rothes,  the Countess. of (Lucy Noel Martha D...

# %%
# titanic['Name'].str.len().sort_values()
# titanic.iloc[307]
titanic['Name'].str.len().max()
# Out:
# 82

# %%
titanic.loc[titanic['Name'].str.len().idxmax()]
# Out:
# PassengerId                                                  308
# Survived                                                       1
# Pclass                                                         1
# Name           Penasco y Castellana, Mrs. Victor de Satode (M...
# Sex                                                       female
# Age                                                           17
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17758
# Fare                                                       108.9
# Cabin                                                        C65
# Embarked                                                       C
# surname        [Penasco y Castellana,  Mrs. Victor de Satode ...
# Name: 307, dtype: object

# %%
titanic['Name'].str.len().idxmax()
# Out:
# 307

# %%
titanic['sex_short'] = titanic['sex_short'].replace('feM' , 'F')
# titanic['sex_short'] = titanic['Sex'].str.replace('male' , 'M')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
